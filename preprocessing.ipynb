# %%
import csv
import pandas as pd
from textblob import TextBlob

# %%
filename = "raw/1429_1.csv"

# %%
with open(filename) as f:
    reader = csv.reader(f)
    items = [x for x in reader]

# %%
df = pd.read_csv(filename)
# Out:
# /Users/heegyukim/.pyenv/versions/bitbyte-text/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# ...

# %%
columns = ['id', 'reviews.title', 'reviews.text', 'reviews.rating']
filtered = df[columns]

# %%
filtered.head()
# Out:
#                      id                            reviews.title  \
# 0  AVqkIhwDv8e3D1O-lebb                                   Kindle
# 1  AVqkIhwDv8e3D1O-lebb                                very fast
# 2  AVqkIhwDv8e3D1O-lebb  Beginner tablet for our 9 year old son.
# 3  AVqkIhwDv8e3D1O-lebb                                  Good!!!
# 4  AVqkIhwDv8e3D1O-lebb                Fantastic Tablet for kids
#
#                                         reviews.text  reviews.rating
# 0  This product so far has not disappointed. My c...             5.0
# 1  great for beginner or experienced person. Boug...             5.0
# 2  Inexpensive tablet for him to use and learn on...             5.0
# 3  I've had my Fire HD 8 two weeks now and I love...             4.0
# 4  I bought this for my grand daughter when she c...             5.0

# %%
titles = df['reviews.title']    
texts = df['reviews.text']
ratings = df['reviews.rating']

# %%
title_blobs = [TextBlob(str(x)) for x in texts]
text_blobs = [TextBlob(str(x)) for x in titles]

# %%
title_sentiments = [b.sentiment.polarity for b in title_blobs]
text_sentiments = [b.sentiment.polarity for b in text_blobs]

# %%
predict_df = pd.DataFrame([(titles[i], texts[i], inratings[i]), title_sentiments[i], text_sentiments[i]) for i in range(len(titles))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5e59d7ec1cbc> in <module>
# ----> 1 predict_df = pd.DataFrame([(titles[i], texts[i], int(ratings[i]), title_sentiments[i], text_sentiments[i]) for i in range(len(titles))])
#
# <ipython-input-35-5e59d7ec1cbc> in <listcomp>(.0)
# ----> 1 predict_df = pd.DataFrame([(titles[i], texts[i], int(ratings[i]), title_sentiments[i], text_sentiments[i]) for i in range(len(titles))])
#
# ValueError: cannot convert float NaN to integer

# %%
predict_df.head()
# Out:
#                                          0  \
# 0                                   Kindle
# 1                                very fast
# 2  Beginner tablet for our 9 year old son.
# 3                                  Good!!!
# 4                Fantastic Tablet for kids
#
#                                                    1    2         3     4
# 0  This product so far has not disappointed. My c...  5.0  0.325000  0.00
# 1  great for beginner or experienced person. Boug...  5.0  0.800000  0.26
# 2  Inexpensive tablet for him to use and learn on...  5.0  0.600000  0.10
# 3  I've had my Fire HD 8 two weeks now and I love...  4.0  0.374583  1.00
# 4  I bought this for my grand daughter when she c...  5.0  0.368056  0.40

# %%
predict_df.to_csv("raw/sentiments.csv", header=True)
